# %% [markdown]
# ## Week 0 HW2
#
# 1. This assignment is an individual effort.
# 2. Submission to be uploaded into your group repositories in the folder python_intro
# 3. Deadline is 20th of April 5:00 PM.
# 4. Please follow google's [python styleguide](https://google.github.io/styleguide/pyguide.html) for your code. Pay attention to the guidelines for naming convention, comments and main.
# 5. Code will be checked for plagiarism. Compelling signs of a duplicated effort will lead to a rejection of submission and will attract a 100\% grade penalty.

# %% [markdown]
# ### 1
# Please load the file provided to you by email. Use _json_ module to read it as a list.

# %%
import json
# 1 use open a connection to the file
# 2 read contents of the file
# 3 use the json module to read the string as a list
#(replace None with relevant code)

file_handle = open("1967_Johnson_Roger.txt")
file_content = file_handle.read()
speech = json.loads(file_content)
print[1]
# print speech[2] for the string of the actual speech, speech[0] for the year and speech[1]
# Out:
# [1]

# %% [markdown]
# Notice that type(speech) is list. Please take a moment to go through the python list documentation and check out the various ways to manipulate lists.

# %% [markdown]
# ###2
# The first element of the list is the year of speech, the second element is the president who gave it, while the third is the transcript of the same.
#
# 1. Inspect the transcript. Note the commonly used non-alphanumerical characters. Use an appropriate method of strings to get rid of them.
# 2. Use an appropriate string method to split the string of the speech into a list of smaller list of words.
# 3. Convert all words into lower case and return the list. Use a for loop. Then use a list comprehension to do the same.

# %%
#1 
import re
stripped_text = re.sub("[^\\w]", " ", speech[2])
#print(stripped_text)

#2
word_list = stripped_text.split()
#print(word_list)

#3 
# 3.1 
lower_words = []
for i in word_list:
    lower_words.append(i.lower())
    
# 3.2
lower_words_comp = [i.lower() for i in word_list]
#print(lower_words_comp)
# Out:
# [u'delivered', u'in', u'person', u'before', u'a', u'joint', u'session', u'at', u'9', u'33', u'p', u'm', u'mr', u'speaker', u'mr', u'vice', u'president', u'distinguished', u'members', u'of', u'the', u'congress', u'i', u'share', u'with', u'all', u'of', u'you', u'the', u'grief', u'that', u'you', u'feel', u'at', u'the', u'death', u'today', u'of', u'one', u'of', u'the', u'most', u'beloved', u'respected', u'and', u'effective', u'members', u'of', u'this', u'body', u'the', u'distinguished', u'representative', u'from', u'rhode', u'island', u'mr', u'fogarty', u'i', u'have', u'come', u'here', u'tonight', u'to', u'report', u'to', u'you', u'that', u'this', u'is', u'a', u'time', u'of', u'testing', u'for', u'our', u'nation', u'at', u'home', u'the', u'question', u'is', u'whether', u'we', u'will', u'continue', u'working', u'for', u'better', u'opportunities', u'for', u'all', u'americans', u'when', u'most', u'americans', u'are', u'already', u'living', u'better', u'than', u'any', u'people', u'in', u'history', u'abroad', u'the', u'question', u'is', u'whether', u'we', u'have', u'the', u'staying', u'power', u'to', u'fight', u'a', u'very', u'costly', u'war', u'when', u'the', u'objective', u'is', u'limited', u'and', u'the', u'danger', u'to', u'us', u'is', u'seemingly', u'remote', u'so', u'our', u'test', u'is', u'not', u'whether', u'we', u'shrink', u'from', u'our', u'country', u's', u'cause', u'when', u'the', u'dangers', u'to', u'us', u'are', u'obvious', u'and', u'dose', u'at', u'hand', u'but', u'rather', u'whether', u'we', u'carry', u'on', u'when', u'they', u'seem', u'obscure', u'and', u'distant', u'and', u'some', u'think', u'that', u'it', u'is', u'safe', u'to', u'lay', u'down', u'our', u'burdens', u'i', u'have', u'come', u'tonight', u'm', u'ask', u'this', u'congress', u'and', u'this', u'nation', u'to', u'resolve', u'that', u'issue', u'to', u'meet', u'our', u'commitments', u'at', u'home', u'and', u'abroad', u'to', u'continue', u'to', u'build', u'a', u'better', u'america', u'and', u'to', u'reaffirm', u'this', u'nation', u's', u'allegiance', u'to', u'freedom', u'as', u'president', u'abraham', u'lincoln', u'said', u'we', u'must', u'ask', u'where', u'we', u'are', u'and', u'whither', u'we', u'are', u'tending', u'i', u'the', u'last', u'3', u'years', u'bear', u'witness', u'to', u'our', u'determination', u'to', u'make', u'this', u'a', u'better', u'country', u'we', u'have', u'struck', u'down', u'legal', u'barriers', u'to', u'equality', u'we', u'have', u'improved', u'the', u'education', u'of', u'7', u'million', u'deprived', u'children', u'and', u'this', u'year', u'alone', u'we', u'have', u'enabled', u'almost', u'1', u'million', u'students', u'to', u'go', u'to', u'college', u'we', u'have', u'brought', u'medical', u'care', u'to', u'older', u'people', u'who', u'were', u'unable', u'to', u'afford', u'it', u'three', u'and', u'one', u'half', u'million', u'americans', u'have', u'already', u'received', u'treatment', u'under', u'medicare', u'since', u'july', u'we', u'have', u'built', u'a', u'strong', u'economy', u'that', u'has', u'put', u'almost', u'3', u'million', u'more', u'americans', u'on', u'the', u'payrolls', u'in', u'the', u'last', u'year', u'alone', u'we', u'have', u'included', u'more', u'than', u'9', u'million', u'new', u'workers', u'under', u'a', u'higher', u'minimum', u'wage', u'we', u'have', u'launched', u'new', u'training', u'programs', u'to', u'provide', u'job', u'skills', u'for', u'almost', u'1', u'million', u'americans', u'we', u'have', u'helped', u'more', u'than', u'a', u'thousand', u'local', u'communities', u'to', u'attack', u'poverty', u'in', u'the', u'neighborhoods', u'of', u'the', u'poor', u'we', u'have', u'set', u'out', u'to', u'rebuild', u'our', u'cities', u'on', u'a', u'scale', u'that', u'has', u'never', u'been', u'attempted', u'before', u'we', u'have', u'begun', u'to', u'rescue', u'our', u'waters', u'from', u'the', u'menace', u'of', u'pollution', u'and', u'to', u'restore', u'the', u'beauty', u'of', u'our', u'land', u'and', u'our', u'countryside', ...

# %% [markdown]
# ### 3
# Create a function _preprocess_ that takes as arguments _text_ and _non_alphanum_, a string of non-alphanumeric characters that you want get rid of. Perform all operations specfied in the previous question. However, converting to lowercase should be an optional argument. The data structure returned should be a list of words.

# %%
def preprocess(text, _nonalphanum, lower = True):
    
    for j in _nonalphanum:
        text = text.replace(j, " ")
    word_list = text.split()
    
    if lower == True:
        word_list = [i.lower() for i in word_list]
    
    return word_list

#list("hola")
preprocess(speech[2], "/\-][.,", lower = True)
# Out:
# [u'delivered',
#  u'in',
#  u'person',
#  u'before',
#  u'a',
#  u'joint',
#  u'session',
#  u'at',
#  u'9:33',
#  u'p',
#  u'm',
#  u'mr',
#  u'speaker',
#  u'mr',
#  u'vice',
#  u'president',
#  u'distinguished',
#  u'members',
#  u'of',
#  u'the',
#  u'congress:',
#  u'i',
#  u'share',
#  u'with',
#  u'all',
#  u'of',
#  u'you',
#  u'the',
#  u'grief',
#  u'that',
#  u'you',
#  u'feel',
#  u'at',
#  u'the',
#  u'death',
#  u'today',
#  u'of',
#  u'one',
#  u'of',
#  u'the',
#  u'most',
#  u'beloved',
#  u'respected',
#  u'and',
#  u'effective',
#  u'members',
#  u'of',
#  u'this',
#  u'body',
#  u'the',
#  u'distinguished',
#  u'representative',
#  u'from',
#  u'rhode',
#  u'island',
#  u'mr',
#  u'fogarty',
#  u'i',
#  u'have',
#  u'come',
#  u'here',
#  u'tonight',
#  u'to',
#  u'report',
#  u'to',
#  u'you',
#  u'that',
#  u'this',
#  u'is',
#  u'a',
#  u'time',
#  u'of',
#  u'testing',
#  u'for',
#  u'our',
#  u'nation',
#  u'at',
#  u'home',
#  u'the',
#  u'question',
#  u'is',
#  u'whether',
#  u'we',
#  u'will',
#  u'continue',
#  u'working',
#  u'for',
#  u'better',
#  u'opportunities',
#  u'for',
#  u'all',
#  u'americans',
#  u'when',
#  u'most',
#  u'americans',
#  u'are',
#  u'already',
#  u'living',
#  u'better',
#  u'than',
#  u'any',
#  u'people',
#  u'in',
#  u'history',
#  u'abroad',
#  u'the',
#  u'question',
#  u'is',
#  u'whether',
#  u'we',
#  u'have',
#  u'the',
#  u'staying',
#  u'power',
#  u'to',
#  u'fight',
#  u'a',
#  u'very',
#  u'costly',
#  u'war',
#  u'when',
#  u'the',
#  u'objective',
#  u'is',
#  u'limited',
#  u'and',
#  u'the',
#  u'danger',
#  u'to',
#  u'us',
#  u'is',
#  u'seemingly',
#  u'remote',
#  u'so',
#  u'our',
#  u'test',
#  u'is',
#  u'not',
#  u'whether',
#  u'we',
#  u'shrink',
#  u'from',
#  u'our',
#  u"country's",
#  u'cause',
#  u'when',
#  u'the',
#  u'dangers',
#  u'to',
#  u'us',
#  u'are',
#  u'obvious',
#  u'and',
#  u'dose',
#  u'at',
#  u'hand',
#  u'but',
#  u'rather',
#  u'whether',
#  u'we',
#  u'carry',
#  u'on',
#  u'when',
#  u'they',
#  u'seem',
#  u'obscure',
#  u'and',
#  u'distant',
#  u'and',
#  u'some',
#  u'think',
#  u'that',
#  u'it',
#  u'is',
#  u'safe',
#  u'to',
#  u'lay',
#  u'down',
#  u'our',
#  u'burdens',
#  u'i',
#  u'have',
#  u'come',
#  u'tonight',
#  u'm',
#  u'ask',
#  u'this',
#  u'congress',
#  u'and',
#  u'this',
#  u'nation',
#  u'to',
#  u'resolve',
#  u'that',
#  u'issue:',
#  u'to',
#  u'meet',
#  u'our',
#  u'commitments',
#  u'at',
#  u'home',
#  u'and',
#  u'abroad',
#  u'to',
#  u'continue',
#  u'to',
#  u'build',
#  u'a',
#  u'better',
#  u'america',
#  u'and',
#  u'to',
#  u'reaffirm',
#  u'this',
#  u"nation's",
#  u'allegiance',
#  u'to',
#  u'freedom',
#  u'as',
#  u'president',
#  u'abraham',
#  u'lincoln',
#  u'said',
#  u'"we',
#  u'must',
#  u'ask',
#  u'where',
#  u'we',
#  u'are',
#  u'and',
#  u'whither',
#  u'we',
#  u'are',
#  u'tending',
#  u'"',
#  u'i',
#  u'the',
#  u'last',
#  u'3',
#  u'years',
#  u'bear',
#  u'witness',
#  u'to',
#  u'our',
#  u'determination',
#  u'to',
#  u'make',
#  u'this',
#  u'a',
#  u'better',
#  u'country',
#  u'we',
#  u'have',
#  u'struck',
#  u'down',
#  u'legal',
#  u'barriers',
#  u'to',
#  u'equality',
#  u'we',
#  u'have',
#  u'improved',
#  u'the',
#  u'education',
#  u'of',
#  u'7',
#  u'million',
#  u'deprived',
#  u'children',
#  u'and',
#  u'this',
#  u'year',
#  u'alone',
#  u'we',
#  u'have',
#  u'enabled',
#  u'almost',
#  u'1',
#  u'million',
#  u'students',
#  u'to',
#  u'go',
#  u'to',
#  u'college',
#  u'we',
#  u'have',
#  u'brought',
#  u'medical',
#  u'care',
#  u'to',
#  u'older',
#  u'people',
#  u'who',
#  u'were',
#  u'unable',
#  u'to',
#  u'afford',
#  u'it',
#  u'three',
#  u'and',
#  u'one',
#  u'half',
#  u'million',
#  u'americans',
#  u'have',
#  u'already',
#  u'received',
#  u'treatment',
#  u'under',
#  u'medicare',
#  u'since',
#  u'july',
#  u'we',
#  u'have',
#  u'built',
#  u'a',
#  u'strong',
#  u'economy',
#  u'that',
#  u'has',
#  u'put',
#  u'almost',
#  u'3',
#  u'million',
#  u'more',
#  u'americans',
#  u'on',
#  u'the',
#  u'payrolls',
#  u'in',
#  u'the',
#  u'last',
#  u'year',
#  u'alone',
#  u'we',
#  u'have',
#  u'included',
#  u'more',
#  u'than',
#  u'9',
#  u'million',
#  u'new',
#  u'workers',
#  u'under',
#  u'a',
#  u'higher',
#  u'minimum',
#  u'wage',
#  u'we',
#  u'have',
#  u'launched',
#  u'new',
#  u'training',
#  u'programs',
#  u'to',
#  u'provide',
#  u'job',
#  u'skills',
#  u'for',
#  u'almost',
#  u'1',
#  u'million',
#  u'americans',
#  u'we',
#  u'have',
#  u'helped',
#  u'more',
#  u'than',
#  u'a',
#  u'thousand',
#  u'local',
#  u'communities',
#  u'to',
#  u'attack',
#  u'poverty',
#  u'in',
#  u'the',
#  u'neighborhoods',
#  u'of',
#  u'the',
#  u'poor',
#  u'we',
#  u'have',
#  u'set',
#  u'out',
#  u'to',
#  u'rebuild',
#  u'our',
#  u'cities',
#  u'on',
#  u'a',
#  u'scale',
#  u'that',
#  u'has',
#  u'never',
#  u'been',
#  u'attempted',
#  u'before',
#  u'we',
#  u'have',
#  u'begun',
#  u'to',
#  u'rescue',
#  u'our',
#  u'waters',
#  u'from',
#  u'the',
#  u'menace',
#  u'of',
#  u'pollution',
#  u'and',
#  u'to',
#  u'restore',
#  u'the',
#  u'beauty',
#  u'of',
#  u'our',
#  u'land',
#  u'and',
#  u'our',
#  u'countryside',
#  u'our',
#  u'cities',
#  u'and',
#  u'our',
#  u'towns',
#  u'we',
#  u'have',
#  u'given',
#  u'1',
#  u'million',
#  u'young',
#  u'americans',
#  u'a',
#  u'chance',
#  u'to',
#  u'earn',
#  u'through',
#  u'the',
#  u'neighborhood',
#  u'youth',
#  u'corps',
#  u'or',
#  u'through',
#  u'head',
#  u'start',
#  u'a',
#  u'chance',
#  u'to',
#  u'learn',
#  u'so',
#  u'together',
#  u'we',
#  u'have',
#  u'tried',
#  u'to',
#  u'meet',
#  u'the',
#  u'needs',
#  u'of',
#  u'our',
#  u'people',
#  u'and',
#  u'we',
#  u'have',
#  u'succeeded',
#  u'in',
#  u'creating',
#  u'a',
#  u'better',
#  u'life',
#  u'for',
#  u'the',
#  u'many',
#  u'as',
#  u'well',
#  u'as',
#  u'the',
#  u'few',
#  u'now',
#  u'we',
#  u'must',
#  u'answer',
#  u'whether',
#  u'our',
#  u'gains',
#  u'shall',
#  u'be',
#  u'the',
#  u'foundations',
#  u'of',
#  u'further',
#  u'progress',
#  u'or',
#  u'whether',
#  u'they',
#  u'shall',
#  u'be',
#  u'only',
#  u'monuments',
#  u'to',
#  u'what',
#  u'might',
#  u'have',
#  u'been',
#  u'abandoned',
#  u'now',
#  u'by',
#  u'a',
#  u'people',
#  u'who',
#  u'lacked',
#  u'the',
#  u'will',
#  u'to',
#  u'see',
#  u'their',
#  u'great',
#  u'work',
#  u'through',
#  u'i',
#  u'believe',
#  u'that',
#  u'our',
#  u'people',
#  u'do',
#  u'not',
#  u'want',
#  u'to',
#  u'quit',
#  u'though',
#  u'the',
#  u'task',
#  u'is',
#  u'great',
#  u'the',
#  u'work',
#  u'hard',
#  u'often',
#  u'frustrating',
#  u'and',
#  u'success',
#  u'is',
#  u'a',
#  u'matter',
#  u'not',
#  u'of',
#  u'days',
#  u'or',
#  u'months',
#  u'but',
#  u'of',
#  u'years',
#  u'and',
#  u'sometimes',
#  u'it',
#  u'may',
#  u'be',
#  u'even',
#  u'decades',
#  u'ii',
#  u'i',
#  u'have',
#  u'come',
#  u'here',
#  u'tonight',
#  u'to',
#  u'discuss',
#  u'with',
#  u'you',
#  u'five',
#  u'ways',
#  u'of',
#  u'carrying',
#  u'forward',
#  u'the',
#  u'progress',
#  u'of',
#  u'these',
#  u'last',
#  u'3',
#  u'years',
#  u'these',
#  u'five',
#  u'ways',
#  u'concern',
#  u'programs',
#  u'partnerships',
#  u'priorities',
#  u'prosperity',
#  u'and',
#  u'peace',
#  u'first',
#  u'programs',
#  u'we',
#  u'must',
#  u'see',
#  u'to',
#  u'it',
#  u'i',
#  u'think',
#  u'that',
#  u'these',
#  u'new',
#  u'programs',
#  u'that',
#  u'we',
#  u'have',
#  u'passed',
#  u'work',
#  u'effectively',
#  u'and',
#  u'are',
#  u'administered',
#  u'in',
#  u'the',
#  u'best',
#  u'possible',
#  u'way',
#  u'three',
#  u'years',
#  u'ago',
#  u'we',
#  u'set',
#  u'out',
#  u'to',
#  u'create',
#  u'these',
#  u'new',
#  u'instruments',
#  u'of',
#  u'social',
#  u'progress',
#  u'this',
#  u'required',
#  u'trial',
#  u'and',
#  u'error',
#  u'and',
#  u'it',
#  u'has',
#  u'produced',
#  u'both',
#  u'but',
#  u'as',
#  u'we',
#  u'learn',
#  u'through',
#  u'success',
#  u'and',
#  u'failure',
#  u'we',
#  u'are',
#  u'changing',
#  u'our',
#  u'strategy',
#  u'and',
#  u'we',
#  u'are',
#  u'trying',
#  u'to',
#  u'improve',
#  u'our',
#  u'tactics',
#  u'in',
#  u'the',
#  u'long',
#  u'run',
#  u'these',
#  u'starts',
#  u'some',
#  u'rewarding',
#  u'others',
#  u'inadequate',
#  u'and',
#  u'disappointing',
#  u'are',
#  u'crucial',
#  u'to',
#  u'success',
#  u'one',
#  u'example',
#  u'is',
#  u'the',
#  u'struggle',
#  u'to',
#  u'make',
#  u'life',
#  u'better',
#  u'for',
#  u'the',
#  u'less',
#  u'fortunate',
#  u'among',
#  u'us',
#  u'on',
#  u'a',
#  u'similar',
#  u'occasion',
#  u'at',
#  u'this',
#  u'rostrum',
#  u'in',
#  u'1949',
#  u'i',
#  u'heard',
#  u'a',
#  u'great',
#  u'american',
#  u'president',
#  u'harry',
#  u's',
#  u'truman',
#  u'declare',
#  u'this:',
#  u'"the',
#  u'american',
#  u'people',
#  u'have',
#  u'decided',
#  u'that',
#  u'poverty',
#  u'is',
#  u'just',
#  u'as',
#  u'wasteful',
#  u'and',
#  u'just',
#  u'as',
#  u'unnecessary',
#  u'as',
#  u'preventable',
#  u'disease',
#  u'"',
#  u'many',
#  u'listened',
#  u'to',
#  u'president',
#  u'truman',
#  u'that',
#  u'day',
#  u'here',
#  u'in',
#  u'this',
#  u'chamber',
#  u'but',
#  u'few',
#  u'understood',
#  u'what',
#  u'was',
#  u'required',
#  u'and',
#  u'did',
#  u'anything',
#  u'about',
#  u'it',
#  u'the',
#  u'executive',
#  u'branch',
#  u'and',
#  u'the',
#  u'congress',
#  u'waited',
#  u'15',
#  u'long',
#  u'years',
#  u'before',
#  u'ever',
#  u'taking',
#  u'any',
#  u'action',
#  u'on',
#  u'that',
#  u'challenge',
#  u'as',
#  u'it',
#  u'did',
#  u'on',
#  u'many',
#  u'other',
#  u'challenges',
#  u'that',
#  u'great',
#  u'president',
#  u'presented',
#  u'and',
#  u'when',
#  u'3',
#  u'years',
#  u'ago',
#  u'you',
#  u'here',
#  u'in',
#  u'the',
#  u'congress',
#  u'joined',
#  u'with',
#  u'me',
#  u'in',
#  u'a',
#  u'declaration',
#  u'of',
#  u'war',
#  u'on',
#  u'poverty',
#  u'then',
#  u'i',
#  u'warned',
#  u'"it',
#  u'will',
#  u'not',
#  u'be',
#  u'a',
#  u'short',
#  u'or',
#  u'easy',
#  u'struggle',
#  u'no',
#  u'single',
#  u'weapon',
#  u'will',
#  u'suffice',
#  u'but',
#  u'we',
#  u'shall',
#  u'not',
#  u'rest',
#  u'until',
#  u'that',
#  u'war',
#  u'is',
#  u'won',
#  u'"',
#  u'and',
#  u'i',
#  u'have',
#  u'come',
#  u'here',
#  u'to',
#  u'renew',
#  u'that',
#  u'pledge',
#  u'tonight',
#  u'i',
#  u'recommend',
#  u'that',
#  u'we',
#  u'intensify',
#  u'our',
#  u'efforts',
#  u'to',
#  u'give',
#  u'the',
#  u'poor',
#  u'a',
#  u'chance',
#  u'to',
#  u'enjoy',
#  u'and',
#  u'to',
#  u'join',
#  u'in',
#  u'this',
#  u"nation's",
#  u'progress',
#  u'i',
#  u'shall',
#  u'propose',
#  u'certain',
#  u'administrative',
#  u'changes',
#  u'suggested',
#  u'by',
#  u'the',
#  u'congress',
#  u'as',
#  u'well',
#  u'as',
#  u'some',
#  u'that',
#  u'we',
#  u'have',
#  u'learned',
#  u'from',
#  u'our',
#  u'own',
#  u'trial',
#  u'and',
#  u'error',
#  u'i',
#  u'shall',
#  u'urge',
#  u'special',
#  u'methods',
#  u'and',
#  u'special',
#  u'funds',
#  u'to',
#  u'reach',
#  u'the',
#  u'hundreds',
#  u'of',
#  u'thousands',
#  u'of',
#  u'americans',
#  u'that',
#  u'are',
#  u'now',
#  u'trapped',
#  u'in',
#  u'the',
#  u'ghettos',
#  u'of',
#  u'our',
#  u'big',
#  u'cities',
#  u'and',
#  u'through',
#  u'head',
#  u'start',
#  u'to',
#  u'try',
#  u'to',
#  u'reach',
#  u'out',
#  u'to',
#  u'our',
#  u'very',
#  u'young',
#  u'little',
#  u'children',
#  u'the',
#  u'chance',
#  u'to',
#  u'learn',
#  u'is',
#  u'their',
#  u'brightest',
#  u'hope',
#  u'and',
#  u'must',
#  u'command',
#  u'our',
#  u'full',
#  u'determination',
#  u'for',
#  u'learning',
#  u'brings',
#  u'skills;',
#  u'and',
#  u'skills',
#  u'bring',
#  u'jobs;',
#  u'and',
#  u'jobs',
#  u'bring',
#  u'responsibility',
#  u'and',
#  u'dignity',
#  u'as',
#  u'well',
#  u'as',
#  u'taxes',
#  u'this',
#  u'war',
#  u'like',
#  u'the',
#  u'war',
#  u'in',
#  u'vietnam',
#  u'is',
#  u'not',
#  u'a',
#  u'simple',
#  u'one',
#  u'there',
#  u'is',
#  u'no',
#  u'single',
#  u'battleline',
#  u'which',
#  u'you',
#  u'can',
#  u'plot',
#  u'each',
#  u'day',
#  u'on',
#  u'a',
#  u'chart',
#  u'the',
#  u'enemy',
#  u'is',
#  u'not',
#  u'easy',
#  u'to',
#  u'perceive',
#  u'or',
#  u'to',
#  u'isolate',
#  u'or',
#  ...]

# %% [markdown]
# ### 4
# Create a function _word_freq_ that takes as input a word list that has been preprocessed and returns a dictionary of the word frequency. Which is the fourth most frequent word of your word list? (Provide code that computes it)

# %%
def _wordfreq(word_list):
    
    wordfreq = [word_list.count(p) for p in word_list]
    return dict(zip(word_list,wordfreq))

wl = preprocess(speech[2], "/\-][.,", lower = True)
wf = _wordfreq(wl)
sorted(wf.items(), key=lambda x: x[1])[(len(wf)-5):(len(wf)-1)]

# The fourth most frequent word is 'we'
# Out:
# [(u'we', 193), (u'of', 202), (u'to', 279), (u'and', 285)]

# %% [markdown]
# ### 5
# Write a function that takes as input a word list and returns a dictionary of the frequencies of word lengths. Do not use the api collections for this assignment. But have a look at its [documentation](https://docs.python.org/2/library/collections.html). Its useful tool to have in your repository.

# %%
def _lenfreq(word_list):
    
    lengths = []
    for i in word_list:
        lengths.append(len(i))
        
    lenfreq = [lengths.count(p) for p in lengths]
    return dict(zip(lengths,lenfreq))


# wl = preprocess(speech[2], "/\-][.,", lower = True)
# wf = _wordfreq(wl)

wl = preprocess(speech[2], "/\-][.,", lower = True)
_lenfreq(wl)
# Out:
# {1: 259,
#  2: 1370,
#  3: 1401,
#  4: 1264,
#  5: 688,
#  6: 571,
#  7: 632,
#  8: 424,
#  9: 270,
#  10: 173,
#  11: 99,
#  12: 38,
#  13: 31,
#  14: 26,
#  15: 4,
#  16: 2}

# %% [markdown]
# ### 6
# Load the file _sou_all.txt_ in ./data/pres_speech. Inspect its contents. Familiarise yourself with using regular expressions in python. You can use this [document](https://docs.python.org/2/howto/regex.html) as a starting point. Now use regular expressions to seperate the different speeches. Your function should accept the text and a regular expression as input and return a list of lists. Each element of the list should be a list with following structure:
#
# 1. year
# 2. president
# 3. List of the transcript of the speech broken down into paragraphs.
#
# Save your result as json

# %%
file_handle = open("sou_all.txt")
file_content = file_handle.read()
speech = json.loads(file_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bc1c61973511> in <module>()
#       1 file_handle = open("sou_all.txt")
#       2 file_content = file_handle.read()
# ----> 3 speech = json.loads(file_content)
#
# NameError: name 'json' is not defined
